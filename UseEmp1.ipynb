# %%
import import_ipynb

from EmpOOP1 import *
from DeprtOOP1 import *
from AddressOOP1 import *

# %%
add01 = address()
try:
    add01 = address()

except (AttributeError, ValueError) as e:
    print("Address Error :", e)

# %%
dep01 = department()
try:
    dep01 = department()

except (AttributeError, ValueError) as e:
    print("Department Error :", e)

# %%
empl01 = employee(dep01,add01)
try:
    empl01 = employee(dep01, add01)
    print("Employee Created Successfully")
    print(empl01.show_emp_details())

except ValueError as e:
    print("Salary Error :", e)

except AttributeError as e:
    print("Name Error :", e)

except Exception as e:
    print("Unexpected Error :", e)




try:
    mag01 = manager(dep01, add01)

    print(mag01.show_emp_details())
    print(mag01.show_manager_total_salary())

except ValueError as e:
    print("Value Error :", e)

except AttributeError as e:
    print("Attribute Error :", e)

except Exception as e:
    print("Unknown Error :", e)




try:
    sale01 = salesman(dep01, add01)

    print(sale01.show_emp_details())
    print(sale01.show_salesman_total_salary())

except ValueError as e:
    print("Value Error :", e)

except AttributeError as e:
    print("Attribute Error :", e)

except Exception as e:
    print("Unknown Error :", e)

finally:
    print("Program Finished")

# %%
empl01.show_emp_details()
# Out:
# ('Employee Name:',
#  'abhi',
#  'Employee ID:',
#  1001,
#  'Employee Salary:',
#  44400,
#  'Employee Department Details:',
#  ('Department Name:', 'ds', 'Department ID:', 'h24354'),
#  'Employee Address Details:',
#  ('Street:', 'hinj', 'City:', 'pune', 'Pincode:', '41004'))

# %%
mag01 = manager(dep01, add01)

# %%
mag01.show_manager_total_salary()
# Out:
# ('Total_Salary:', 6978)

# %%
"""# Polymorphism
def processEmpdetails(emp01):
    print(type(emp01))
    print(emp01.show_emp_details())
    print(emp01.show_total_salary())
    processEmpdetails(emp01)"""
# Out:
# '# Polymorphism\ndef processEmpdetails(emp01):\n    print(type(emp01))\n    print(emp01.show_emp_details())\n    print(emp01.show_total_salary())\n    processEmpdetails(emp01)'
