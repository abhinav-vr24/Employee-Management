# %%
class employee:
    next_emp_id = 1001      # Class variable

    def __init__(self, empname, salary):
        self.empid = employee.next_emp_id
        employee.next_emp_id += 1
        self.empname = empname
        self.sal()

    # Raising the Error
    def sal (self, salary):
        if salary <= 0:
            raise ValueError("Salary Can not be -ve")
        else:
            self.salary = salary


    def getdeptdetails(self):        #Association with Department
        return self.department.show_dept_details()
    
    def getadressdetails(self):     #Association with Address
        return self.show_address_details()



    def show_emp_details(self):
        return (
            "Employee Name:", self.empname,
            "Employee ID:", self.empid,
            "Employee Salary:", self.salary
        )

    def show_total_salary(self):
        pass


# Child Class1
class manager(employee):

    def __init__(self, empname, salary, perks):
        super().__init__(empname, salary)
        self.perks = perks

    def show_total_salary(self):
        return self.salary + self.perks


# Child Class2
class salesman(employee):

    def __init__(self, empname, salary, comission):
        super().__init__(empname, salary)
        self.comission = comission

    def show_total_salary(self):
        return self.salary + self.comission





# ---------------------------------------------------------
# Association Example (as shown in the notebook)
# ---------------------------------------------------------

class employee:
    next_emp_id = 1001      # Class variable

    def __init__(self, empname, salary, deptobj, addobj):
        self.empid = employee.next_emp_id
        employee.next_emp_id += 1

        # Add Association of Department with employee
        self.department = deptobj
        self.address = addobj

        if len(empname) < 0:
            raise AttributeError("Employee Name can not be empty")
        else:
            self.empname = empname

        if salary <= 0:
            raise ValueError("Salary Can not be -ve")
        else:
            self.salary = salary

    # GETTER

# %%
# Polymorphism
def processEmpdetails(emp01):
    print(type(emp01))
    print(emp01.show_emp_details())
    print(emp01.show_total_salary())
    processEmpdetails(emp01)
